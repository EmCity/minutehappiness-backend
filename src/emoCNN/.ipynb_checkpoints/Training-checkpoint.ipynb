# %% [markdown]
# ** The CNN network for happiness recognition**
#
# We implement the recognition of emotion, which will be used for labeling videos.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2


# GPU
gpu_device = 0
torch.cuda.set_device(gpu_device)
print('Chosen GPU device: ' + str(torch.cuda.current_device()))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Chosen GPU device: 0

# %%
from make_dataloader import *
import pickle
load = False
batch_size = 75
try:
    if load:
        loaders = pickle.load(open("./fer2013/fer2013Loaders.p","rb"))
    else:
        make_dataloader(only_two = True, batch_size = batch_size)
        loaders = pickle.load(open("./fer2013/fer2013Loaders.p","rb"))
except (OSError, IOError) as e:
    make_dataloader(only_two = True, batch_size = batch_size)
    loaders = pickle.load(open("./fer2013/fer2013Loaders.p","rb"))
# Out:
# Data preprocessed and loaders saved in :
# ./fer2013/fer2013Loaders.p

# %%
train_loader = loaders['train_loader']
valid_loader = loaders['valid_loader']
test_loader = loaders['test_loader']

# %%
a = 0
for img,j in train_loader:
    plt.figure(figsize = (10,1))
    plt.imshow(img[0].numpy()[0], cmap="Greys_r")
    plt.show()
    a+=1
    if a >4:
        break

# %%
from emoCNN import *
import emoSolver
model = emoCNNnet(kernels = [12,6])
solver = emoSolver.emoSolver(optim_args={"lr": 0.01})
# Out:
# <bound method Module.parameters of emoCNNnet (
#   (feature): Sequential (
#     (0): Conv2d(1, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU ()
#     (2): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (3): ReLU ()
#     (4): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (5): Conv2d(12, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (6): ReLU ()
#     (7): Conv2d(6, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (8): ReLU ()
#     (9): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   )
#   (classifier): Sequential (
#     (0): Linear (864 -> 100)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True)
#     (2): ReLU ()
#     (3): Linear (100 -> 2)
#   )
# )>

# %%
a = 0
for img,j in train_loader:
    result = model(Variable(img).cuda(0))
    
    for i in range(20):
        plt.figure(figsize = (10,1))
        plt.imshow(img[i].numpy()[0], cmap="Greys_r")
        
        plt.show()    
        print(result[i])
    break
# Out:
# Variable containing:
# -0.2921
# -0.1167
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.2499
# -0.0633
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.1081
# -0.1600
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.2038
# -0.4000
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.5785
# -0.1419
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
# 1.00000e-02 *
#  -6.4167
#  -3.4920
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.2069
# -0.1395
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
# -0.0203
# -0.3761
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.0074
# -0.1682
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.1023
# -0.0010
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.4001
# -0.1974
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
# 1.00000e-02 *
#  -4.4988
#   9.6127
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.1670
# -0.1969
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
# 1.00000e-02 *
#  -6.2964
#  -8.8082
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.1438
# -0.1665
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
# -0.0372
# -0.3839
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.4830
# -0.3382
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.1507
# -0.0077
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.0767
# -0.2533
# [torch.cuda.FloatTensor of size 2 (GPU 0)]
# Variable containing:
#  0.3537
# -0.3019
# [torch.cuda.FloatTensor of size 2 (GPU 0)]

# %%
solver.train(model, train_loader, valid_loader, log_nth=100, num_epochs=1)
# Out:
# START TRAIN.
# [iteration 0/47] TRAIN loss : 0.448445
# [iteration 0/47] VALID acc/loss : 0.744000/0.547078
# [Epoch 0/1] TRAIN acc/loss : 0.773333/0.549843
# [Epoch 0/1] VALID acc/loss : 0.749333/0.513717
# FINISH.

# %%
import matplotlib.pyplot as plt
plt.subplot(2, 1, 1)
plt.plot(solver.train_loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')
print(solver.train_acc_history)
plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()
# Out:
# [0.77333333333333332]

# %%
model.save('../emoCNNtrivial.p')
# Out:
# Saving model... ../emoCNNtrivial.p

# %%
m = torch.load('../emoCNNtrivial.p')
m
# Out:
# emoCNNnet (
#   (feature): Sequential (
#     (0): Conv2d(1, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): ReLU ()
#     (2): Conv2d(12, 12, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (3): ReLU ()
#     (4): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#     (5): Conv2d(12, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (6): ReLU ()
#     (7): Conv2d(6, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (8): ReLU ()
#     (9): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   )
#   (classifier): Sequential (
#     (0): Linear (864 -> 100)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True)
#     (2): ReLU ()
#     (3): Linear (100 -> 2)
#   )
# )

# %%
from ... import modelInterface
processImagesBatch(['../../images/video1/1.jpg', '../../images/video1/2.jpg'])

# %%
#testing the final model
t_loss, t_acc = solver.get_valid_stats(model, test_loader)
